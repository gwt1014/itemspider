# %%
import requests
from bs4 import BeautifulSoup
from lxml import etree
import re
import time
import random
import pandas as pd
from multiprocessing.dummy import Pool

# %%
#淘宝和天猫的 搜索页面
init_searchurl_taobao ='https://s.taobao.com/search?'
#淘宝和天猫的商品链接
init_itemurl_tmall = 'https://detail.tmall.com/item.htm?id={}'
init_itemurl_taobao = 'https://item.taobao.com/item.htm?id={}'

headers={
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'zh-CN,zh;q=0.9',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.62 Safari/537.36'
        }
#淘宝搜索页面
init_searchurl_taobao ='https://s.taobao.com/search?'

# %%
def getitemurls_taobao(target,sort='sale-desc',maxpage=1):
    itemurls = {}
    itemurl_taobao = []
    itemurl_tmall = []
    for page in range(0,maxpage):
        params = {
                    'q' : target,
                    'sort' : sort,
                    's' : str(44*(page))
        }
        res = requests.get(init_searchurl_taobao,params=params,headers=headers)
        ids = re.findall('"nid":"(.*?)","category"',res.text,re.S)
        urls = re.findall('"detail_url":"//(.*?)","view_price"',res.text,re.S)
#        print(len(ids))
#        print(len(urls))
        if len(ids) == 0:
            print('被干了这次不算')
        info = dict(ids = ids , urls=urls)
        for i in range(0,len(ids)):
        #由于淘宝页面返回的URL是带//OOOC3这种乱码的，所以url只是看一下到底是淘宝还是天猫，并不作为真正的url传回去
        #返回的URL是用init_itemurl拼出来的
            if 'tmall' in info['urls'][i]:
                itemurl_tmall.append(init_itemurl_tmall.format(info['ids'][i]))
            elif 'taobao' in info['urls'][i]:
                itemurl_taobao.append(init_itemurl_taobao.format(info['ids'][i]))  
#        print("稍等一下")
        time.sleep(random.randint(0,1))
    itemurls['tmall'] = itemurl_tmall
    itemurls['taobao'] = itemurl_taobao
    print('共有商品%d个，其中淘宝%d个，天猫%d个'%((len(itemurl_tmall)+len(itemurl_taobao)),len(itemurl_taobao),len(itemurl_tmall)))
    return itemurls

# %%
#获取淘宝的商品信息
def getitemInfo_taobao(itemUrl):
    res = openlink(itemUrl)
    print("获取商品: "+ res.url)
    selector = etree.HTML(res.text)

    title = selector.xpath("//h3[@class='tb-main-title']/@data-title")[0]

    price = selector.xpath("//em[@class = 'tb-rmb-num']/text()")[0] # 淘宝

    itemID = re.findall('id=(\d+)',res.url)[0]

    itemDetail = "".join(selector.xpath('//div[@class="attributes"]/ul/li/text()'))

    shopUrl = selector.xpath('//div[@class="tb-shop-search"]/div/form/@action')[0].lstrip('//').rstrip('search.htm')

    shopId = re.findall('shopId=(.*?);',selector.xpath('//meta[@name="microscope-data"]/@content')[0])[0]

    #获取评论信息 
    res_com = openlink(init_commentUrl_taobao.format(itemID))
    jc = json.loads(res_com.text.lstrip('\r\n(').rstrip(')'))
    #评论数
    totalComment = jc['data']['count']['total']
    #好评数
    good = jc['data']['count']['good']
    #中评数
    normal = jc['data']['count']['normal']
    #差评数
    bad = jc['data']['count']['bad']

    itemInfo = pd.DataFrame(dict(title=title,
                             price=price,
                            itemID=itemID,
                            itemDetail=[itemDetail],
                            itemLink =res.url,
                            shopUrl = shopUrl,
                             shopId  = shopId,
                             totalComment = totalComment,
                             good = good,
                             normal = normal,
                             bad = bad
                            ),
                            columns=['itemID','itemLink','title' ,'price','totalComment','good','normal', 'bad','itemDetail','shopId','shopUrl'])
    return itemInfo

# %%
# 获取天猫的商品信息
def getitemInfo_tmall(itemUrl):
    res = openlink(itemUrl)
    print("获取商品: "+ res.url)
    selector = etree.HTML(res.text)    
    title = selector.xpath("//div[@class='tb-detail-hd']/h1/text()")[0].replace(' ','').replace('\t','').replace('\r','').replace('\n','')
    price = re.findall('"defaultItemPrice":"(.*?)"',res.text)[0]
    itemID = re.findall('id=(\d+)',res.url)[0]
    itemDetail = "".join(selector.xpath('//div[@class="attributes"]/div/ul/li/text()'))

    shopUrl = selector.xpath('//div[@class="slogo"]/a/@href')[0].lstrip('//')
    shopId = selector.xpath('//div[@id="LineZing"]/@shopid')

    #获取评论信息 

    res_com = openlink(init_commentUrl_tmall.format(itemID))

    jc = json.loads(res_com.text.lstrip('\r\njsonp128(').rstrip(')\n'))

    #评论数
    totalComment = jc['dsr']['rateTotal']

    #评分
    score = jc['dsr']['gradeAvg']

    itemInfo = pd.DataFrame(dict(title=title,
                                 price=price,
                                itemID=itemID,
                                itemDetail=[itemDetail],
                                itemLink =res.url,
                                shopUrl = shopUrl,
                                 shopId  = shopId,
                                 totalComment = totalComment,
                                 score = score,
                                ),columns=['itemID','itemLink','title' ,'price','totalComment','score','itemDetail','shopId','shopUrl'])
    return itemInfo

# %%
def openlink(link):
    maxTryNum = 10
    for tries in range(0,maxTryNum):
        try:
            res = requests.get(link, headers = headers)
            return res
        except:
            if tries < (maxTryNum - 1):
                print("啊呀")
                continue
            else:
                print("Has tried %d times to access url %s, all failed!", maxNum, link)
                break

# %%
target = '行车记录仪'
itemUrl = getitemurls_taobao(target,maxpage=10)
# Out:
# 共有商品440个，其中淘宝92个，天猫348个

# %%
info_taobao =[]
info_tmall = []

pool = Pool(8)
time3 =time.time()
info_taobao = pool.map(getitemInfo_taobao,itemUrl['taobao'])
info_tmall = pool.map(getitemInfo_tmall,itemUrl['tmall'])
pool.close()
pool.join()

time4 =time.time()
print(str(time4-time3))
# Out:
# 获取商品: https://item.taobao.com/item.htm?id=543765804129
# 获取商品: https://item.taobao.com/item.htm?id=571908069396
# 获取商品: https://item.taobao.com/item.htm?id=573718312859
# 获取商品: https://item.taobao.com/item.htm?id=564169946669
# 获取商品: https://item.taobao.com/item.htm?id=573124175136
# 获取商品: https://item.taobao.com/item.htm?id=571946780901
# 获取商品: https://item.taobao.com/item.htm?id=574246632987
# 获取商品: https://item.taobao.com/item.htm?id=526397484286
# 获取商品: https://item.taobao.com/item.htm?id=526464949581
# 获取商品: https://item.taobao.com/item.htm?id=534159083192
# 获取商品: https://item.taobao.com/item.htm?id=568772214439
# 获取商品: https://item.taobao.com/item.htm?id=561869766169
# 获取商品: https://item.taobao.com/item.htm?id=559369594465
# 获取商品: https://item.taobao.com/item.htm?id=570460460638
# 获取商品: https://item.taobao.com/item.htm?id=567334843228
# 获取商品: https://item.taobao.com/item.htm?id=571602104591
# 获取商品: https://item.taobao.com/item.htm?id=567482957351
# 获取商品: https://item.taobao.com/item.htm?id=570931994258
# 获取商品: https://item.taobao.com/item.htm?id=570805785090
# 获取商品: https://item.taobao.com/item.htm?id=566582867367
# 获取商品: https://item.taobao.com/item.htm?id=569660711620
# 获取商品: https://item.taobao.com/item.htm?id=567860485024
# 获取商品: https://item.taobao.com/item.htm?id=569668895195
# 获取商品: https://detail.tmall.com/item.htm?id=562654988033
# 获取商品: https://detail.tmall.com/item.htm?id=530368115745
# 获取商品: https://detail.tmall.com/item.htm?id=521861612001
# 获取商品: https://detail.tmall.com/item.htm?id=529108527916
# 获取商品: https://detail.tmall.com/item.htm?id=43050287980
# 获取商品: https://detail.tmall.com/item.htm?id=574851463284
# 获取商品: https://detail.tmall.com/item.htm?id=573016570127
# 啊呀
# 获取商品: https://detail.tmall.com/item.htm?id=565772682287
# 获取商品: https://detail.tmall.com/item.htm?id=573548174434
# 获取商品: https://detail.tmall.com/item.htm?id=568320189029
# 获取商品: https://detail.tmall.com/item.htm?id=565680820027
# 获取商品: https://detail.tmall.com/item.htm?id=566004579541
# 获取商品: https://detail.tmall.com/item.htm?id=561076976861
# 获取商品: https://detail.tmall.com/item.htm?id=557495771970
# 获取商品: https://detail.tmall.com/item.htm?id=574389514316
# 获取商品: https://detail.tmall.com/item.htm?id=569512704517
# 啊呀
# 获取商品: https://detail.tmall.com/item.htm?id=562615469083
# 获取商品: https://detail.tmall.com/item.htm?id=527127114203
# 获取商品: https://detail.tmall.com/item.htm?id=573187424812
# 获取商品: https://detail.tmall.com/item.htm?id=568779667283
# 获取商品: https://detail.tmall.com/item.htm?id=40606939819
# 获取商品: https://detail.tmall.com/item.htm?id=560983557851
# 获取商品: https://detail.tmall.com/item.htm?id=567023738544
# 获取商品: https://detail.tmall.com/item.htm?id=561406217861
# 获取商品: https://detail.tmall.com/item.htm?id=526970420019
# 获取商品: https://detail.tmall.com/item.htm?id=574078929902
# 获取商品: https://detail.tmall.com/item.htm?id=574969988249
# 获取商品: https://detail.tmall.com/item.htm?id=568966867331
# 获取商品: https://detail.tmall.com/item.htm?id=567340994332
# 啊呀
# 获取商品: https://detail.tmall.com/item.htm?id=555547639371
# 获取商品: https://detail.tmall.com/item.htm?id=566064217628
# 获取商品: https://detail.tmall.com/item.htm?id=562534459015
# 获取商品: https://detail.tmall.com/item.htm?id=572400974908
# 获取商品: https://detail.tmall.com/item.htm?id=567254900228
# 啊呀
# 获取商品: https://detail.tmall.com/item.htm?id=572770700231
# 获取商品: https://detail.tmall.com/item.htm?id=526977733364
# 啊呀
# 获取商品: https://detail.tmall.com/item.htm?id=574924292883
# 获取商品: https://detail.tmall.com/item.htm?id=567228151640
# 啊呀
# 获取商品: https://detail.tmall.com/item.htm?id=566581977281
# 获取商品: https://detail.tmall.com/item.htm?id=567400513685
# 啊呀
# 获取商品: https://detail.tmall.com/item.htm?id=555250356571
# 获取商品: https://detail.tmall.com/item.htm?id=537628563929
# 啊呀
# 获取商品: https://detail.tmall.com/item.htm?id=569905411890
# 啊呀
# 获取商品: https://detail.tmall.com/item.htm?id=573538403333
# 获取商品: https://detail.tmall.com/item.htm?id=571266928974
# 获取商品: https://detail.tmall.com/item.htm?id=567190620821
# 获取商品: https://detail.tmall.com/item.htm?id=572509750754
# 获取商品: https://detail.tmall.com/item.htm?id=573492599182
# 啊呀
# 获取商品: https://detail.tmall.com/item.htm?id=571317315460
# 获取商品: https://detail.tmall.com/item.htm?id=571852743530
# 获取商品: https://detail.tmall.com/item.htm?id=537248739482
# 啊呀
# 啊呀
# 获取商品: https://detail.tmall.com/item.htm?id=573390439892
# 获取商品: https://detail.tmall.com/item.htm?id=521171927697
# 啊呀
# 获取商品: https://detail.tmall.com/item.htm?id=540604793314
# 获取商品: https://detail.tmall.com/item.htm?id=551135938164
# 获取商品: https://detail.tmall.com/item.htm?id=566545071413
# 啊呀
# 获取商品: https://detail.tmall.com/item.htm?id=560338079276
# 啊呀
# 获取商品: https://detail.tmall.com/item.htm?id=530449141177
# 208.62124061584473

# %%
tb = pd.concat(info_taobao,ignore_index=True)
tm = pd.concat(info_tmall,ignore_index=True)
df = pd.merge(tb,tm,how='outer')
df.to_csv(str('output/'+target+'-info-' +str(time.strftime("%Y-%m-%d"))+'.csv'))

# %%
t = str(time.time()*1000).split('.')

# %%
print('%s_%s' % (t[0], t[1]))
# Out:
# 1534742516729_3755
